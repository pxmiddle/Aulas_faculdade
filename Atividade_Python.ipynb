# %% [markdown]
# <a href="https://colab.research.google.com/github/pxmiddle/Aulas_faculdade/blob/main/Atividade_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-cc0649d8-a37b-4094-b84e-c3b0d0a83373" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc0649d8-a37b-4094-b84e-c3b0d0a83373">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Eu.png to Eu (1).png

# %%
imagem= plt.imread('Eu.png')

# %%
plt.imshow(imagem)

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-2f9cd610-a36a-4d25-b451-62f8efb265c2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f9cd610-a36a-4d25-b451-62f8efb265c2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving top.png to top.png

# %%
foto = plt.imread('top.png')

# %%
plt.imshow(foto)

# %%
plt.imshow(foto[:,:,0], cmap='gray')

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-62f83b01-204f-4b44-baf4-c8b378ab0972" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-62f83b01-204f-4b44-baf4-c8b378ab0972">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ceobe.jpg to ceobe.jpg

# %%
ceobe = plt.imread('ceobe.jpg')

# %%
plt.imshow(ceobe)
plt.xticks([],[])
plt.yticks([],[])
# Out:
# ([], [])

# %%
import PIL

# %%
from PIL import Image, ImageOps

# %%
Nvs = Image.open('saga.jpg')

# %%
Nvs
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=165x171 at 0x7F284C32E410>

# %%
gray_image = ImageOps.grayscale(Nvs)

# %%
gray_image
# Out:
# <PIL.Image.Image image mode=L size=165x171 at 0x7F284C443110>

# %%
minhaFoto = Image.open('Eu.png')

# %%
minhaFoto

# %%
print(minhaFoto.size)
# Out:
# (1024, 1024)

# %%
redi = minhaFoto.resize((150, 150))
redi
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F284C330290>

# %%
rota = redi.rotate(60)
rota
# Out:
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F284C304350>

# %%
Gatos = Image.open('gatos.jpg')
rd = Gatos.resize((240, 150))
rd
# Out:
# <PIL.Image.Image image mode=RGB size=240x150 at 0x7F284C423E50>

# %%
rt = rd.rotate(180)
rt
# Out:
# <PIL.Image.Image image mode=RGB size=240x150 at 0x7F284C7D9190>
